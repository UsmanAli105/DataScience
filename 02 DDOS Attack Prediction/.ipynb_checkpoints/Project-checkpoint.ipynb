# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("dataset_sdn-.csv")

# %%
list(df.columns)
# Out:
# ['dt',
#  'switch',
#  'src',
#  'dst',
#  'pktcount',
#  'bytecount',
#  'dur',
#  'dur_nsec',
#  'tot_dur',
#  'flows',
#  'packetins',
#  'pktperflow',
#  'byteperflow',
#  'pktrate',
#  'Pairflow',
#  'Protocol',
#  'port_no',
#  'tx_bytes',
#  'rx_bytes',
#  'tx_kbps',
#  'rx_kbps',
#  'tot_kbps',
#  'label']

# %%
df.head()
# Out:
#       dt  switch       src       dst  pktcount  bytecount  dur   dur_nsec  \
# 0  11425       1  10.0.0.1  10.0.0.8     45304   48294064  100  716000000
# 1  11605       1  10.0.0.1  10.0.0.8    126395  134737070  280  734000000
# 2  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 3  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
# 4  11425       1  10.0.0.2  10.0.0.8     90333   96294978  200  744000000
#
#         tot_dur  flows  ...  pktrate  Pairflow  Protocol  port_no   tx_bytes  \
# 0  1.010000e+11      3  ...      451         0       UDP        3  143928631
# 1  2.810000e+11      2  ...      451         0       UDP        4       3842
# 2  2.010000e+11      3  ...      451         0       UDP        1       3795
# 3  2.010000e+11      3  ...      451         0       UDP        2       3688
# 4  2.010000e+11      3  ...      451         0       UDP        3       3413
#
#   rx_bytes  tx_kbps  rx_kbps  tot_kbps  label
# ...

# %%
df.dtypes
# Out:
# dt               int64
# switch           int64
# src             object
# dst             object
# pktcount         int64
# bytecount        int64
# dur              int64
# dur_nsec         int64
# tot_dur        float64
# flows            int64
# packetins        int64
# pktperflow       int64
# byteperflow      int64
# pktrate          int64
# Pairflow         int64
# Protocol        object
# port_no          int64
# tx_bytes         int64
# rx_bytes         int64
# tx_kbps          int64
# rx_kbps        float64
# tot_kbps       float64
# label            int64
# dtype: object

# %%
cat_cols = list(n for n in df.columns if df[n].dtype == "object")
cat_cols
# Out:
# ['src', 'dst', 'Protocol']

# %%
cardinality_of_cat_cols = {n:len(list(df[n].unique())) for n in cat_cols}
cardinality_of_cat_cols
# Out:
# {'src': 19, 'dst': 18, 'Protocol': 3}

# %%
name_of_cat_cols = {n:list(df[n].unique()) for n in cat_cols}
name_of_cat_cols
# Out:
# {'src': ['10.0.0.1',
#   '10.0.0.2',
#   '10.0.0.4',
#   '10.0.0.10',
#   '10.0.0.3',
#   '10.0.0.5',
#   '10.0.0.13',
#   '10.0.0.6',
#   '10.0.0.20',
#   '10.0.0.11',
#   '10.0.0.12',
#   '10.0.0.18',
#   '10.0.0.8',
#   '10.0.0.7',
#   '10.0.0.9',
#   '10.0.0.14',
#   '10.0.0.15',
#   '10.0.0.16',
#   '10.0.0.17'],
#  'dst': ['10.0.0.8',
#   '10.0.0.7',
#   '10.0.0.3',
#   '10.0.0.5',
#   '10.0.0.10',
#   '10.0.0.13',
#   '10.0.0.1',
#   '10.0.0.11',
#   '10.0.0.2',
#   '10.0.0.4',
#   '10.0.0.9',
#   '10.0.0.6',
#   '10.0.0.14',
#   '10.0.0.15',
#   '10.0.0.12',
#   '10.0.0.16',
#   '10.0.0.17',
#   '10.0.0.18'],
#  'Protocol': ['UDP', 'TCP', 'ICMP']}

# %%
size_of_df = len(df)
size_of_df
# Out:
# 104345

# %%
df_altered = df.drop(['src', 'dst'], axis=1).copy()

# %%
df_altered
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  ...  pktrate  Pairflow  Protocol  \
# ...

# %%
mapping = {}
for i, j in enumerate(list(df.Protocol.unique())):
    mapping[j] = i
mapping
# Out:
# {'UDP': 0, 'TCP': 1, 'ICMP': 2}

# %%
df_altered.Protocol = df_altered.Protocol.map(mapping)

# %%
df_altered
# Out:
#            dt  switch  pktcount  bytecount  dur   dur_nsec       tot_dur  \
# 0       11425       1     45304   48294064  100  716000000  1.010000e+11
# 1       11605       1    126395  134737070  280  734000000  2.810000e+11
# 2       11425       1     90333   96294978  200  744000000  2.010000e+11
# 3       11425       1     90333   96294978  200  744000000  2.010000e+11
# 4       11425       1     90333   96294978  200  744000000  2.010000e+11
# ...       ...     ...       ...        ...  ...        ...           ...
# 104340   5262       3        79       7742   81  842000000  8.184200e+10
# 104341   5262       3        79       7742   81  842000000  8.184200e+10
# 104342   5262       3        31       3038   31  805000000  3.180500e+10
# 104343   5262       3        31       3038   31  805000000  3.180500e+10
# 104344   5262       3        31       3038   31  805000000  3.180500e+10
#
#         flows  packetins  pktperflow  ...  pktrate  Pairflow  Protocol  \
# ...

# %%
cor = df_altered.corr()
plt.figure(figsize=(20, 20))
plt.label = "Correlation of all the features"
sns.heatmap(cor, annot=True)
# Out:
# <Axes: >

# %%
df_altered.columns = df_altered.columns.astype(str)

# %%
df_altered.columns
# Out:
# Index(['dt', 'switch', 'pktcount', 'bytecount', 'dur', 'dur_nsec', 'tot_dur',
#        'flows', 'packetins', 'pktperflow', 'byteperflow', 'pktrate',
#        'Pairflow', 'Protocol', 'port_no', 'tx_bytes', 'rx_bytes', 'tx_kbps',
#        'rx_kbps', 'tot_kbps', 'label'],
#       dtype='object')

# %%
for i in df_altered.columns:
    plt.figure(figsize=(8, 6))
    plt.hist(df_altered[i], edgecolor='black')
    plt.xlabel = str(i)  
    plt.title = f'Histogram of {str(i)}'
    # plt.savefig("./imgs/"+i+"_histogram.png")  
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 4
#       2 plt.figure(figsize=(8, 6))
#       3 plt.hist(df_altered[i], edgecolor='black')
# ----> 4 plt.xlabel(str(i))  # Use plt.xlabel() to set the x-axis label
#       5 plt.title(f'Histogram of {str(i)}')
#       6 # plt.savefig("./imgs/"+i+"_histogram.png")  # Uncomment this line to save the plots as images
#
# TypeError: 'str' object is not callable

# %%
for i in df_altered.columns[0:-1]:
    plt.scatter(x=df_altered[i], y=df_altered['label'])
    plt.label=i
#     plt.savefig("./imgs/"+i+"_histogram.png")
    plt.show()

# %%
df_altered.columns[0:-1]
# Out:
# Index(['dt', 'switch', 'pktcount', 'bytecount', 'dur', 'dur_nsec', 'tot_dur',
#        'flows', 'packetins', 'pktperflow', 'byteperflow', 'pktrate',
#        'Pairflow', 'Protocol', 'port_no', 'tx_bytes', 'rx_bytes', 'tx_kbps',
#        'rx_kbps', 'tot_kbps'],
#       dtype='object')
